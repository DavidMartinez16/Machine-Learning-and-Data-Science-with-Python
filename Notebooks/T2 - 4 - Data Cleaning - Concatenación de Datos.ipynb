# %% [markdown]
# # Concatenar y Apendizar Datasets

# %%
import pandas as pd

# %%
red_wine = pd.read_csv('../datasets/wine/winequality-red.csv', sep=';')
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
red_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
white_wine = pd.read_csv('../datasets/wine/winequality-white.csv', sep=';')
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
white_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# En Python tenemos 2 tipos de ejes,
# * axis = 0 denota el eje horizontal
# * axis = 1 denota el eje vertical

# %%
wine_data = pd.concat([white_wine, red_wine], axis = 0)

# %%
wine_data.shape
# Out:
# (6497, 12)

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
wine_data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
data1 = wine_data.head(10)
data2 = wine_data[300:310]
data3 = wine_data.tail(10)

# %%
wine_scramble = pd.concat([data1, data2, data3], axis = 0)

# %%
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# 5               8.1             0.280         0.40             6.9      0.050
# 6               6.2             0.320         0.16             7.0      0.045
# 7               7.0             0.270         0.36            20.7      0.045
# 8               6.3             0.300         0.34             1.6      0.049
# 9               8.1             0.220         0.43             1.5      0.044
# 300             6.1             0.410         0.00             1.6      0.063
# ...

# %% [markdown]
# # Datos Distribuidos

# %%
data1 = pd.read_csv('../datasets/distributed-data/001.csv')
data1.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data1.shape
# Out:
# (1461, 4)

# %%
data1.describe()
# Out:
#           sulfate     nitrate      ID
# count  117.000000  122.000000  1461.0
# mean     3.880701    0.549910     1.0
# std      2.831156    0.380921     0.0
# min      0.613000    0.118000     1.0
# 25%      2.210000    0.283500     1.0
# 50%      2.870000    0.453000     1.0
# 75%      4.730000    0.663500     1.0
# max     19.100000    1.830000     1.0

# %% [markdown]
# * Importar el primer fichero
# * Hacemos un bucle para ir recorriendo todos y cada uno de los ficheros, tener consistencia en el nombre de los ficheros
# * Importar los ficheros uno a uno cada uno de ellos debe añadirse al final del primer fichero cargado
# * Repetir el bucle hasta cubrir todos los ficheros

# %%
filepath='../datasets/distributed-data/'

data = pd.read_csv('../datasets/distributed-data/001.csv')
final_length = len(data)

for i in range(2,333):
    if i < 10:
        filename = '00'+str(i)
    elif 10 <= i < 100:
        filename = '0'+str(i)
    elif i >= 100:
        filename = str(i)
    file = filepath + filename + '.csv'
    
    temp_data = pd.read_csv(file)
    
    final_length += len(temp_data)

    data = pd.concat([data, temp_data], axis = 0)

# %%
data.shape
# Out:
# (772087, 4)

# %%
data.isnull().sum()
# Out:
# Date            0
# sulfate    653304
# nitrate    657738
# ID              0
# dtype: int64

# %%
data.tail()
# Out:
#            Date  sulfate  nitrate   ID
# 726  2004-12-27      NaN      NaN  332
# 727  2004-12-28      NaN      NaN  332
# 728  2004-12-29      NaN      NaN  332
# 729  2004-12-30      NaN      NaN  332
# 730  2004-12-31      NaN      NaN  332

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
final_length
# Out:
# 772087

# %% [markdown]
# ## Join Datasets

# %%
filepath = '../datasets/athletes/'

data_main = pd.read_csv(filepath + "Medals.csv", encoding = 'ISO-8859-1')

# %%
data_main.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# 3              2              3             6
# 4              1              3             6

# %%
a = data_main['Athlete'].unique().tolist()
len(a)
# Out:
# 6956

# %%
data_country = pd.read_csv(filepath + 'Athelete_Country_Map.csv',encoding = 'ISO-8859-1')

# %%
data_country.head()
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States

# %%
data_country[data_country['Athlete'] == "Aleksandar Ciric"]
# Out:
#                Athlete                Country
# 1029  Aleksandar Ciric                 Serbia
# 1086  Aleksandar Ciric  Serbia and Montenegro

# %%
data_sports = pd.read_csv(filepath + 'Athelete_Sports_Map.csv', encoding = 'ISO-8859-1')

# %%
data_sports.head()
# Out:
#             Athlete       Sport
# 0    Michael Phelps    Swimming
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming

# %%
data_sports.shape
# Out:
# (6975, 2)

# %%
data_sports[data_sports['Athlete'] == 'Chen Jing']
# Out:
#         Athlete         Sport
# 1308  Chen Jing    Volleyball
# 1419  Chen Jing  Table Tennis

# %%
# Elimina los datos duplicados
data_country_dp = data_country.drop_duplicates(subset = "Athlete")

# %%
data_main_country = pd.merge(left = data_main, right = data_country_dp, 
                            left_on = "Athlete", right_on = "Athlete")

# %%
data_main_country.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %%
data_main_country.shape
# Out:
# (8618, 9)

# %%
data_main_country[data_main_country['Athlete'] == "Aleksandar Ciric"]
# Out:
#                Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 1491  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1492  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1493  Aleksandar Ciric  22.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals Country
# 1491              0              1             1  Serbia
# 1492              1              0             1  Serbia
# 1493              0              1             1  Serbia

# %%
data_sports_dp = data_sports.drop_duplicates(subset = "Athlete")

# %%
len(data_sports_dp) == len(a)
# Out:
# True

# %%
data_final = pd.merge(left = data_main_country, right = data_sports_dp, left_on = "Athlete", right_on = "Athlete")

# %%
data_final.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country     Sport
# 0              0              0             8  United States  Swimming
# 1              0              2             8  United States  Swimming
# 2              2              0             6  United States  Swimming
# 3              2              3             6  United States  Swimming
# 4              2              1             5  United States  Swimming

# %%
data_final.shape
# Out:
# (8618, 10)

# %% [markdown]
# # Tipos de Joins

# %%
from IPython.display import Image
import numpy as np

# %%
out = np.random.choice(data_main["Athlete"], size = 6, replace = False)

# %%
out
# Out:
# array(['Richard Thompson', 'Mansur Isayev', 'Kim Gyeong-Seok',
#        'Meb Keflezighi', 'Bob Merrick', 'Andrey Kravchenko'], dtype=object)

# %%
data_country_dlt = data_country_dp[(~data_country_dp["Athlete"].isin(out)) & 
                                   (data_country_dp["Athlete"] != "Michael Phelps")]

data_sports_dlt = data_sports_dp[(~data_sports_dp["Athlete"].isin(out)) & 
                                 (data_sports_dp["Athlete"] != "Michael Phelps")]

data_main_dlt = data_main[(~data_main["Athlete"].isin(out)) & 
                            (data_main["Athlete"] != "Michael Phelps")]

# %%
len(data_country_dlt)
# Out:
# 6949

# %%
len(data_sports_dlt)
# Out:
# 6949

# %%
len(data_main_dlt)
# Out:
# 8607

# %% [markdown]
# ## Inner Join
#
# Esta es la opción predeterminada. Si no se especifica el tipo de unión, se establecerá de manera predeterminada como la unión interna. Esto implica que si estamos uniendo dos tablas en una columna común, solo retornaran los datos que coincidan en ambas tablas
#
# * Devuelve las filas compartidas o en común entre los dos conjuntos de datos

# %%
Image(filename = "../Resources/inner.png")

# %%
# Data Main contiene toda la info
# Data Country Dlt le falta la info de 7 atletas
merged_inner = pd.merge(left = data_main, right = data_country_dlt, 
                       how = 'inner', left_on = "Athlete", right_on = "Athlete")

# %%
merged_inner.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Natalie Coughlin  25.0  2008            08/24/2008            1
# 1  Natalie Coughlin  21.0  2004            08/29/2004            2
# 2  Natalie Coughlin  29.0  2012            08/12/2012            0
# 3     Aleksey Nemov  24.0  2000            10/01/2000            2
# 4     Alicia Coutts  24.0  2012            08/12/2012            1
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              2              3             6  United States
# 1              2              1             5  United States
# 2              0              1             1  United States
# 3              1              3             6         Russia
# 4              3              1             5      Australia

# %% [markdown]
# ## Left Join
#
# Este tipo de unión significa que solo retornan todos los datos de la tabla de la mano izquierda, solo si los datos coinciden con la tabla de la mano derecha
#
# * Devuelve las filas que tuvieran el valor en el dataset de la izquierda, sin importar si tienen correspondencia en el de la derecha o no

# %%
Image(filename = "../Resources/left.png")

# %%
merged_left = pd.merge(left = data_main, right = data_country_dlt,
                      how = "left", left_on = "Athlete", right_on = "Athlete")

# %%
len(merged_left)
# Out:
# 8618

# %%
merged_left.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8            NaN
# 1              0              2             8            NaN
# 2              2              0             6            NaN
# 3              2              3             6  United States
# 4              1              3             6         Russia

# %% [markdown]
# ## Right Join
#
# Este tipo de unión es el caso opuesto al anterior. Implica que solo retornaran los datos de la tabla de la mano derecha, solo si los datos coinciden con la tabla de la mano izquierda
#
# * Devuelve las filas que tuvieran el valor en el dataset de la derecha, sin importar si tienen correspondencia en el de la izquierda o no

# %%
Image(filename = "../Resources/right.png")

# %%
merged_right = pd.merge(left = data_main_dlt, right = data_country_dp,
                      how = "right", left_on = "Athlete", right_on = "Athlete")

# %%
len(merged_right)
# Out:
# 8614

# %%
merged_right.head()
# Out:
#             Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps   NaN     NaN                   NaN          NaN
# 1  Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 2  Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
# 3  Natalie Coughlin  29.0  2012.0            08/12/2012          0.0
# 4     Aleksey Nemov  24.0  2000.0            10/01/2000          2.0
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0            NaN            NaN           NaN  United States
# 1            2.0            3.0           6.0  United States
# 2            2.0            1.0           5.0  United States
# 3            0.0            1.0           1.0  United States
# 4            1.0            3.0           6.0         Russia

# %% [markdown]
# ## Outer Join

# %%
data_country_jd = data_country_dlt.append(
    {
        "Athlete" : "Juan David Martínez",
        "Country" : "Polombia"
    }, ignore_index = True
)

# %%
merged_outter = pd.merge(left = data_main, right = data_country_jd,
                        how = "outer", left_on = "Athlete", right_on = "Athlete")

# %%
len(merged_outter)
# Out:
# 8619

# %%
merged_outter.head()
# Out:
#             Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008.0            08/24/2008          8.0
# 1    Michael Phelps  19.0  2004.0            08/29/2004          6.0
# 2    Michael Phelps  27.0  2012.0            08/12/2012          4.0
# 3  Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 4  Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0            0.0            0.0           8.0            NaN
# 1            0.0            2.0           8.0            NaN
# 2            2.0            0.0           6.0            NaN
# 3            2.0            3.0           6.0  United States
# 4            2.0            1.0           5.0  United States

# %%
merged_outter.tail()
# Out:
#                    Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 8614      Kateryna Serdiuk  17.0  2000.0            10/01/2000          0.0
# 8615      Wietse van Alten  21.0  2000.0            10/01/2000          0.0
# 8616  Sandra Wagner-Sachse  31.0  2000.0            10/01/2000          0.0
# 8617             Rod White  23.0  2000.0            10/01/2000          0.0
# 8618   Juan David Martínez   NaN     NaN                   NaN          NaN
#
#       Silver Medals  Bronze Medals  Total Medals        Country
# 8614            1.0            0.0           1.0        Ukraine
# 8615            0.0            1.0           1.0    Netherlands
# 8616            0.0            1.0           1.0        Germany
# 8617            0.0            1.0           1.0  United States
# 8618            NaN            NaN           NaN       Polombia
